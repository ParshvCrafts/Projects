# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This is a pratice notebook that I created to learn features of Jupyter Notebook, and I have listed some of the Data Science Tools and Ecosystem that will be useful in the long run for career.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List popular libraries for Data Science
# - Insert code and markdown cells

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. SQL
# 3. R
# 4. Scala
# 5. Julia
# 6. Javascript

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Numpy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Tensorflow

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# |Apache Spark|
# |Apache Hadoop|
# |Rstudio|
# |Jupyter Notebooks|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours
minutes= 200
hours= minutes/ 60
round(hours, 3)
# Out:
# 3.333

# %% [markdown]
# <hr>

# %% [markdown]
# ## Author
# - [Parshv Patel](#name)
